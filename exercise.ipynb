# %%
import pandas as pd

# Replace with your modified export URL
exercise_ref = {
"lower_leg" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=257804473",
"upper_leg" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=482297257",
"core_abs" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=1336694795",
"glutes" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=1634570113",
"shoulder" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=2054009488",
"chest" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=1339723243",
"biceps" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=1855529716",
"triceps" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=482281573",
"back" : "https://docs.google.com/spreadsheets/d/1zhu-sCLdTYTKW2zTagkjzqVQgT5-qBIWG0QG0zqWMbs/export?format=csv&gid=1619293202"
}

# %%
# Out:
# <method-wrapper '__str__' of str object at 0x112b6e0b0>

# %%
for key, val in exercise_ref.items():
    try:
        # Read the CSV directly from the URL
        df = pd.read_csv(val)
        
        # Print the first 5 rows to verify

        print("Successfully fetched the data!")
        # print(df.head())
        
        # Example of using the data: Print a specific column
        # print(df['Your_Column_Name'])

    except Exception as e:
        print(f"An error occurred: {e}")

    sorted = df.sort_values(by=['Primary Muscles', 'Secondary Muscles', 'Gym Equipment Needed']).reset_index(drop=True)
    # sorted.to_csv(f'exercises/{key}.csv')
    print(key)
    print(df[sorted.duplicated(subset=['Primary Muscles', 'Secondary Muscles', 'Gym Equipment Needed'], keep=False)])
# Out:
# Successfully fetched the data!
# lower_leg
# Empty DataFrame
# Columns: [Exercise Name, Primary Muscles, Secondary Muscles, Gym Equipment Needed, Movement Mechanics]
# Index: []
# Successfully fetched the data!
# upper_leg
# Empty DataFrame
# Columns: [Exercise Name, Primary Muscles, Secondary Muscles, Gym Equipment Needed, Movement Mechanics]
# Index: []
# Successfully fetched the data!
# core_abs
# Empty DataFrame
# Columns: [Exercise Name, Primary Muscles, Secondary Muscles, Gym Equipment Needed, Movement Mechanics]
# Index: []
# Successfully fetched the data!
# glutes
# Empty DataFrame
# Columns: [Exercise Name, Primary Muscles, Secondary Muscles, Gym Equipment Needed, Movement Mechanics]
# Index: []
# Successfully fetched the data!
# shoulder
# Empty DataFrame
# Columns: [Exercise Name, Primary Muscles, Secondary Muscles, Gym Equipment Needed, Movement Mechanics]
# Index: []
# Successfully fetched the data!
# chest
# Empty DataFrame
# ...

# %%
primary_muscles.to_csv(f'exercises/')
# Out:
#              Exercise Name                Primary Muscles  \
# 0             Dumbbell Fly               Pectoralis Major
# 1   Machine Fly (Pec Deck)               Pectoralis Major
# 2       Cable Standing Fly               Pectoralis Major
# 3            Depth Push-Up               Pectoralis Major
# 4             Clap Push-Up               Pectoralis Major
# 5   Single Arm Cable Press               Pectoralis Major
# 6      Machine Chest Press               Pectoralis Major
# 7        Cable Incline Fly  Pectoralis Major (Clavicular)
# 8     Incline Dumbbell Fly  Pectoralis Major (Clavicular)
# 9      Incline Bench Press  Pectoralis Major (Clavicular)
# 10        Decline Push-Ups  Pectoralis Major (Clavicular)
# 11  Incline Dumbbell Press  Pectoralis Major (Clavicular)
# 12            Pike Push-Up  Pectoralis Major (Clavicular)
# 13     Barbell Bench Press     Pectoralis Major (Sternal)
# 14    Dumbbell Bench Press     Pectoralis Major (Sternal)
# ...
